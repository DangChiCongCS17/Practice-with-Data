# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df =pd.read_csv('car_sample_data1.csv')

# %%
df
# Out:
#       No  Symboling Normalized-losses         Make Fuel-type Aspiration  \
# 0      1          3                 ?  alfa-romero       gas        std
# 1      2          3                 ?  alfa-romero       gas        std
# 2      3          1                 ?  alfa-romero       gas        std
# 3      4          2               164         audi       gas        std
# 4      5          2               164         audi       gas        std
# ..   ...        ...               ...          ...       ...        ...
# 259  260          0               161       peugot       gas        std
# 260  261          0               161       peugot    diesel      turbo
# 261  262          0               161       peugot       gas      turbo
# 262  263          1               119     plymouth       gas        std
# 263  264          1               119     plymouth       gas      turbo
#
#     Num-of-doors   Body-style Drive-wheels Engine-location  ...  Fuel-system  \
# ...

# %%
#+ Check length "drive-wheels", if >5 then remove
a = df['Drive-wheels']
x = range(263)
for i in x:
    if len(a[i]) > 5:
      a = a.drop(labels = [i])

# %%
a
# Out:
# 0      rwd
# 1      rwd
# 2      rwd
# 3      fwd
# 4      4wd
#       ...
# 258    rwd
# 259    rwd
# 260    rwd
# 261    rwd
# 263    fwd
# Name: Drive-wheels, Length: 256, dtype: object

# %%
# + Check NA "price" column
df['Price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 259    16630
# 260    17950
# 261    18150
# 262     5572
# 263     7957
# Name: Price, Length: 264, dtype: object

# %%
df['Price'].isnull().values.sum()
# Out:
# 11

# %%
#At first we have 264 rows × 28 columns, after removing 11 NaN rows , 
# we have now 253 rows × 28 columns
df = df[df['Price'].notnull()]

# %%
# remove non numeric values rows in Price column
df[df['Price'].apply(lambda x: not x.isnumeric())]
b = df[df['Price'].apply(lambda x: not x.isnumeric())]

# %%
b
# Out:
#       No  Symboling Normalized-losses           Make Fuel-type Aspiration  \
# 9     10          0                 ?           audi       gas      turbo
# 44    45          1                 ?          isuzu       gas        std
# 45    46          0                 ?          isuzu       gas        std
# 72    73          3               142  mercedes-benz       gas        std
# 113  114          0                 ?         peugot       gas        std
# 129  130          1                 ?        porsche       gas        std
#
#     Num-of-doors   Body-style Drive-wheels Engine-location  ...  Fuel-system  \
# 9            two    hatchback          4wd           front  ...         mpfi
# 44           two        sedan          fwd           front  ...         2bbl
# 45          four        sedan          fwd           front  ...         2bbl
# 72           two  convertible          rwd           front  ...         mpfi
# ...

# %%
for j in range(len(b)):
    df = df.drop(b.index[j])

# %%
#df = df.drop([df.index[9], df.index[44], df.index[45], df.index[72], df.index[113], df.index[129]])

# %%
df
# Out:
#       No  Symboling Normalized-losses         Make Fuel-type Aspiration  \
# 0      1          3                 ?  alfa-romero       gas        std
# 1      2          3                 ?  alfa-romero       gas        std
# 2      3          1                 ?  alfa-romero       gas        std
# 3      4          2               164         audi       gas        std
# 4      5          2               164         audi       gas        std
# ..   ...        ...               ...          ...       ...        ...
# 259  260          0               161       peugot       gas        std
# 260  261          0               161       peugot    diesel      turbo
# 261  262          0               161       peugot       gas      turbo
# 262  263          1               119     plymouth       gas        std
# 263  264          1               119     plymouth       gas      turbo
#
#     Num-of-doors   Body-style Drive-wheels Engine-location  ...  Fuel-system  \
# ...

# %%
df.index[9]
# Out:
# 11

# %%
#+ Check "Height, Width, Length, Engine-size, Bore, Stroke" 
# datatype, if not interger then remove
df.dtypes
# Out:
# No                     int64
# Symboling              int64
# Normalized-losses     object
# Make                  object
# Fuel-type             object
# Aspiration            object
# Num-of-doors          object
# Body-style            object
# Drive-wheels          object
# Engine-location       object
# Wheel-base           float64
# Length                object
# Width                 object
# Height                object
# Curb-weight            int64
# Engine-type           object
# Num-of-cylinders      object
# Engine-size           object
# Fuel-system           object
# Bore                  object
# Stroke                object
# Compression-ratio    float64
# Horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# Price                 object
# Load-date             object
# dtype: object

# %%
df['Height']
# Out:
# 0      48.8
# 1      48.8
# 2      52.4
# 3      54.3
# 4      54.3
#        ...
# 259    56.7
# 260    56.7
# 261      56
# 262    50.8
# 263    50.8
# Name: Height, Length: 247, dtype: object

# %%
df = df[df.Height.apply(lambda x: x.isnumeric())]

# %%
df['Height']
# Out:
# 19     52
# 20     52
# 117    56
# 146    53
# 147    53
# 156    53
# 158    53
# 160    53
# 167    52
# 168    52
# 169    52
# 170    52
# 171    52
# 178    52
# 179    52
# 211    53
# 225    52
# 226    52
# 253    53
# 254    53
# 261    56
# Name: Height, dtype: object

# %%
df
# Out:
#       No  Symboling Normalized-losses       Make Fuel-type Aspiration  \
# 19    20          1                98  chevrolet       gas        std
# 20    21          0                81  chevrolet       gas        std
# 117  118          0               161     peugot       gas      turbo
# 146  147          0                89     subaru       gas        std
# 147  148          0                89     subaru       gas        std
# 156  157          0                91     toyota       gas        std
# 158  159          0                91     toyota    diesel        std
# 160  161          0                91     toyota       gas        std
# 167  168          2               134     toyota       gas        std
# 168  169          2               134     toyota       gas        std
# 169  170          2               134     toyota       gas        std
# 170  171          2               134     toyota       gas        std
# ...

# %%
df['Width']
# Out:
# 19     63.6
# 20     63.6
# 117    68.3
# 146    65.4
# 147    65.4
# 156    64.4
# 158    64.4
# 160    64.4
# 167    65.6
# 168    65.6
# 169    65.6
# 170    65.6
# 171    65.6
# 178    67.7
# 179    67.7
# 211    64.4
# 225    63.6
# 226    63.6
# 253    65.4
# 254    65.4
# 261    68.3
# Name: Width, dtype: object

# %%
# + Check duplicate
df.duplicated()
# Out:
# 19     False
# 20     False
# 117    False
# 146    False
# 147    False
# 156    False
# 158    False
# 160    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 178    False
# 179    False
# 211    False
# 225    False
# 226    False
# 253    False
# 254    False
# 261    False
# dtype: bool

# %%
# + Rename column "Fuel-type" to "type", "Num-of-cylinders" to "Num_cylinders"
df = df.rename(columns={'Fuel-type':'type','Num-of-cylinders':'Num_cylinders'})

# %%
df
# Out:
#       No  Symboling Normalized-losses       Make    type Aspiration  \
# 19    20          1                98  chevrolet     gas        std
# 20    21          0                81  chevrolet     gas        std
# 117  118          0               161     peugot     gas      turbo
# 146  147          0                89     subaru     gas        std
# 147  148          0                89     subaru     gas        std
# 156  157          0                91     toyota     gas        std
# 158  159          0                91     toyota  diesel        std
# 160  161          0                91     toyota     gas        std
# 167  168          2               134     toyota     gas        std
# 168  169          2               134     toyota     gas        std
# 169  170          2               134     toyota     gas        std
# 170  171          2               134     toyota     gas        std
# 171  172          2               134     toyota     gas        std
# ...

# %%
# Anonimize "dayUpdate" column to "1"
df['Load-date']
# Out:
# 19     2/22/2001
# 20     2/23/2001
# 117    5/31/2001
# 146    6/29/2001
# 147    6/30/2001
# 156     7/9/2001
# 158    7/11/2001
# 160    7/13/2001
# 167    7/20/2001
# 168    7/21/2001
# 169    7/22/2001
# 170    7/23/2001
# 171    7/24/2001
# 178    7/31/2001
# 179     8/1/2001
# 211     7/9/2001
# 225    2/22/2001
# 226    2/23/2001
# 253    6/29/2001
# 254    6/30/2001
# 261    5/31/2001
# Name: Load-date, dtype: object

# %%
type('Load-date')
# Out:
# str

# %%
change1 = pd.to_datetime(df['Load-date'])

# %%
type(change1)
# Out:
# pandas.core.series.Series

# %%
df['Load-date'] = change1

# %%
df['Load-date']
# Out:
# 19    2001-02-22
# 20    2001-02-23
# 117   2001-05-31
# 146   2001-06-29
# 147   2001-06-30
# 156   2001-07-09
# 158   2001-07-11
# 160   2001-07-13
# 167   2001-07-20
# 168   2001-07-21
# 169   2001-07-22
# 170   2001-07-23
# 171   2001-07-24
# 178   2001-07-31
# 179   2001-08-01
# 211   2001-07-09
# 225   2001-02-22
# 226   2001-02-23
# 253   2001-06-29
# 254   2001-06-30
# 261   2001-05-31
# Name: Load-date, dtype: datetime64[ns]

# %%
df['Load-date'] = change1.apply(lambda dt: dt.replace(day = 1))

# %%
df
# Out:
#       No  Symboling Normalized-losses       Make    type Aspiration  \
# 19    20          1                98  chevrolet     gas        std
# 20    21          0                81  chevrolet     gas        std
# 117  118          0               161     peugot     gas      turbo
# 146  147          0                89     subaru     gas        std
# 147  148          0                89     subaru     gas        std
# 156  157          0                91     toyota     gas        std
# 158  159          0                91     toyota  diesel        std
# 160  161          0                91     toyota     gas        std
# 167  168          2               134     toyota     gas        std
# 168  169          2               134     toyota     gas        std
# 169  170          2               134     toyota     gas        std
# 170  171          2               134     toyota     gas        std
# 171  172          2               134     toyota     gas        std
# ...
